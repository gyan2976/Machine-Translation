# %% [markdown]
# **This code is Seq2Seq (Machine Translation) for English to French language**
#
# **Encoder(LSTM) - Decoder(LSTM)**
#
# **BLEU, ROUGE, METEOR**

# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Import Library**

# %%
# !python -m spacy download en_core_web_sm
# !python -m spacy download fr_core_news_sm
# !pip install datasets
# !pip install torchtext==0.14.0
# !pip install rouge-score

# %%
import os, sys, re
import time, math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import spacy, random
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
import tqdm
import torch
import torchtext
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pad_sequence
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# **Step 2: Load Dataset**

# %%
# Load your dataset from CSV
data = pd.read_csv('/content/drive/MyDrive/Interview/eng-french.csv')
data.rename(columns={'English words/sentences': 'en', 'French words/sentences': 'fr'}, inplace=True)
data.head(5)
# Out:
#      en          fr
# 0   Hi.      Salut!
# 1  Run!     Cours !
# 2  Run!    Courez !
# 3  Who?       Qui ?
# 4  Wow!  Ça alors !

# %%
data.shape
# Out:
# (175621, 2)

# %%
train_df, temp_df = train_test_split(data, test_size=0.3, random_state=42)
valid_df, test_df = train_test_split(temp_df, test_size=0.33, random_state=42)  # 0.33 * 0.3 ≈ 0.1

# %%
from datasets import Dataset

train_dataset = Dataset.from_pandas(train_df)
valid_dataset = Dataset.from_pandas(valid_df)
test_dataset = Dataset.from_pandas(test_df)

# %%
train_dataset = train_dataset.remove_columns("__index_level_0__")
valid_dataset = valid_dataset.remove_columns("__index_level_0__")
test_dataset = test_dataset.remove_columns("__index_level_0__")

# %%
from datasets import DatasetDict

# %%
# Create a DatasetDict
dataset_dict = DatasetDict({
    'train': train_dataset,
    'validation': valid_dataset,
    'test': test_dataset
})

# %%
dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['en', 'fr'],
#         num_rows: 122934
#     })
#     validation: Dataset({
#         features: ['en', 'fr'],
#         num_rows: 35300
#     })
#     test: Dataset({
#         features: ['en', 'fr'],
#         num_rows: 17387
#     })
# })

# %%
train_data, valid_data, test_data = (
    dataset_dict["train"],
    dataset_dict["validation"],
    dataset_dict["test"],
)

# %%
train_data[0]
# Out:
# {'en': "We've been spotted.", 'fr': 'Nous avons été repérés.'}

# %%
train_data.shape, valid_data.shape, test_data.shape
# Out:
# ((122934, 2), (35300, 2), (17387, 2))

# %%
# Load SpaCy models
en_nlp = spacy.load('en_core_web_sm')
fr_nlp = spacy.load('fr_core_news_sm')

# %%
string = "What a lovely day it is today!"

[token.text for token in en_nlp.tokenizer(string)]
# Out:
# ['What', 'a', 'lovely', 'day', 'it', 'is', 'today', '!']

# %%
def tokenize_example(example, en_nlp, fr_nlp, max_length, lower, sos_token, eos_token):
    en_tokens = [token.text for token in en_nlp.tokenizer(example["en"])][:max_length]
    fr_tokens = [token.text for token in fr_nlp.tokenizer(example["fr"])][:max_length]
    if lower:
        en_tokens = [token.lower() for token in en_tokens]
        fr_tokens = [token.lower() for token in fr_tokens]
    en_tokens = [sos_token] + en_tokens + [eos_token]
    fr_tokens = [sos_token] + fr_tokens + [eos_token]
    return {"en_tokens": en_tokens, "fr_tokens": fr_tokens}

# %%
max_length = 1_000
lower = True
sos_token = "<sos>"
eos_token = "<eos>"

fn_kwargs = {
    "en_nlp": en_nlp,
    "fr_nlp": fr_nlp,
    "max_length": max_length,
    "lower": lower,
    "sos_token": sos_token,
    "eos_token": eos_token,
}

train_data = train_data.map(tokenize_example, fn_kwargs=fn_kwargs)
valid_data = valid_data.map(tokenize_example, fn_kwargs=fn_kwargs)
test_data = test_data.map(tokenize_example, fn_kwargs=fn_kwargs)
# Out:
# Map:   0%|          | 0/122934 [00:00<?, ? examples/s]
# Map:   0%|          | 0/35300 [00:00<?, ? examples/s]
# Map:   0%|          | 0/17387 [00:00<?, ? examples/s]

# %%
train_data[0]
# Out:
# {'en': "We've been spotted.",
#  'fr': 'Nous avons été repérés.',
#  'en_tokens': ['<sos>', 'we', "'ve", 'been', 'spotted', '.', '<eos>'],
#  'fr_tokens': ['<sos>', 'nous', 'avons', 'été', 'repérés', '.', '<eos>']}

# %%
min_freq = 2
unk_token = "<unk>"
pad_token = "<pad>"

special_tokens = [
    unk_token,
    pad_token,
    sos_token,
    eos_token,
]

en_vocab = torchtext.vocab.build_vocab_from_iterator(
    train_data["en_tokens"],
    min_freq=min_freq,
    specials=special_tokens,
)

fr_vocab = torchtext.vocab.build_vocab_from_iterator(
    train_data["fr_tokens"],
    min_freq=min_freq,
    specials=special_tokens,
)

# %%
en_vocab.get_itos()[:10]
# Out:
# ['<unk>', '<pad>', '<sos>', '<eos>', '.', 'i', 'you', 'to', 'the', '?']

# %%
en_vocab.get_itos()[9]
# Out:
# '?'

# %%
fr_vocab.get_itos()[:10]
# Out:
# ['<unk>', '<pad>', '<sos>', '<eos>', '.', 'je', 'de', '?', 'pas', 'est']

# %%
en_vocab.get_stoi()["the"]
# Out:
# 8

# %%
en_vocab["the"]
# Out:
# 8

# %%
len(en_vocab), len(fr_vocab)
# Out:
# (8513, 13285)

# %%
"the" in en_vocab
# Out:
# True

# %%
"The" in en_vocab
# Out:
# False

# %%
assert en_vocab[unk_token] == fr_vocab[unk_token]
assert en_vocab[pad_token] == fr_vocab[pad_token]

unk_index = en_vocab[unk_token]
pad_index = en_vocab[pad_token]

# %%
en_vocab.set_default_index(unk_index)
fr_vocab.set_default_index(unk_index)

# %%
en_vocab["The"]
# Out:
# 0

# %%
en_vocab.get_itos()[0]
# Out:
# '<unk>'

# %%
tokens = ["i", "love", "watching", "crime", "shows"]

# %%
en_vocab.lookup_indices(tokens)
# Out:
# [5, 139, 609, 1176, 2684]

# %%
en_vocab.lookup_tokens(en_vocab.lookup_indices(tokens))
# Out:
# ['i', 'love', 'watching', 'crime', 'shows']

# %%
def numericalize_example(example, en_vocab, fr_vocab):
    en_ids = en_vocab.lookup_indices(example["en_tokens"])
    fr_ids = fr_vocab.lookup_indices(example["fr_tokens"])
    return {"en_ids": en_ids, "fr_ids": fr_ids}

# %%
fn_kwargs = {"en_vocab": en_vocab, "fr_vocab": fr_vocab}

train_data = train_data.map(numericalize_example, fn_kwargs=fn_kwargs)
valid_data = valid_data.map(numericalize_example, fn_kwargs=fn_kwargs)
test_data = test_data.map(numericalize_example, fn_kwargs=fn_kwargs)
# Out:
# Map:   0%|          | 0/122934 [00:00<?, ? examples/s]
# Map:   0%|          | 0/35300 [00:00<?, ? examples/s]
# Map:   0%|          | 0/17387 [00:00<?, ? examples/s]

# %%
train_data[0]
# Out:
# {'en': "We've been spotted.",
#  'fr': 'Nous avons été repérés.',
#  'en_tokens': ['<sos>', 'we', "'ve", 'been', 'spotted', '.', '<eos>'],
#  'fr_tokens': ['<sos>', 'nous', 'avons', 'été', 'repérés', '.', '<eos>'],
#  'en_ids': [2, 24, 54, 99, 3510, 4, 3],
#  'fr_ids': [2, 27, 98, 80, 0, 4, 3]}

# %%
en_vocab.lookup_tokens(train_data[0]["en_ids"])
# Out:
# ['<sos>', 'we', "'ve", 'been', 'spotted', '.', '<eos>']

# %%
data_type = "torch"
format_columns = ["en_ids", "fr_ids"]

train_data = train_data.with_format(
    type=data_type, columns=format_columns, output_all_columns=True
)

valid_data = valid_data.with_format(
    type=data_type,
    columns=format_columns,
    output_all_columns=True,
)

test_data = test_data.with_format(
    type=data_type,
    columns=format_columns,
    output_all_columns=True,
)

# %%
train_data[0]
# Out:
# {'en_ids': tensor([   2,   24,   54,   99, 3510,    4,    3]),
#  'fr_ids': tensor([ 2, 27, 98, 80,  0,  4,  3]),
#  'en': "We've been spotted.",
#  'fr': 'Nous avons été repérés.',
#  'en_tokens': ['<sos>', 'we', "'ve", 'been', 'spotted', '.', '<eos>'],
#  'fr_tokens': ['<sos>', 'nous', 'avons', 'été', 'repérés', '.', '<eos>']}

# %%
type(train_data[0]["en_ids"])
# Out:
# torch.Tensor

# %%
def get_collate_fn(pad_index):
    def collate_fn(batch):
        batch_en_ids = [example["en_ids"] for example in batch]
        batch_fr_ids = [example["fr_ids"] for example in batch]
        batch_en_ids = nn.utils.rnn.pad_sequence(batch_en_ids, padding_value=pad_index)
        batch_fr_ids = nn.utils.rnn.pad_sequence(batch_fr_ids, padding_value=pad_index)
        batch = {
            "en_ids": batch_en_ids,
            "fr_ids": batch_fr_ids,
        }
        return batch

    return collate_fn

# %%
def get_data_loader(dataset, batch_size, pad_index, shuffle=False):
    collate_fn = get_collate_fn(pad_index)
    data_loader = torch.utils.data.DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        collate_fn=collate_fn,
        shuffle=shuffle,
    )
    return data_loader

# %%
batch_size = 128

train_data_loader = get_data_loader(train_data, batch_size, pad_index, shuffle=True)
valid_data_loader = get_data_loader(valid_data, batch_size, pad_index)
test_data_loader = get_data_loader(test_data, batch_size, pad_index)

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, n_layers, dropout):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers
        self.embedding = nn.Embedding(input_dim, embedding_dim)
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, n_layers, dropout=dropout)
        self.dropout = nn.Dropout(dropout)

    def forward(self, src):
        # src = [src length, batch size]
        embedded = self.dropout(self.embedding(src))
        # embedded = [src length, batch size, embedding dim]
        outputs, (hidden, cell) = self.rnn(embedded)
        # outputs = [src length, batch size, hidden dim * n directions]
        # hidden = [n layers * n directions, batch size, hidden dim]
        # cell = [n layers * n directions, batch size, hidden dim]
        # outputs are always from the top hidden layer
        return hidden, cell

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, embedding_dim, hidden_dim, n_layers, dropout):
        super().__init__()
        self.output_dim = output_dim
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers
        self.embedding = nn.Embedding(output_dim, embedding_dim)
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, n_layers, dropout=dropout)
        self.fc_out = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, input, hidden, cell):
        # input = [batch size]
        # hidden = [n layers * n directions, batch size, hidden dim]
        # cell = [n layers * n directions, batch size, hidden dim]
        # n directions in the decoder will both always be 1, therefore:
        # hidden = [n layers, batch size, hidden dim]
        # context = [n layers, batch size, hidden dim]
        input = input.unsqueeze(0)
        # input = [1, batch size]
        embedded = self.dropout(self.embedding(input))
        # embedded = [1, batch size, embedding dim]
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        # output = [seq length, batch size, hidden dim * n directions]
        # hidden = [n layers * n directions, batch size, hidden dim]
        # cell = [n layers * n directions, batch size, hidden dim]
        # seq length and n directions will always be 1 in this decoder, therefore:
        # output = [1, batch size, hidden dim]
        # hidden = [n layers, batch size, hidden dim]
        # cell = [n layers, batch size, hidden dim]
        prediction = self.fc_out(output.squeeze(0))
        # prediction = [batch size, output dim]
        return prediction, hidden, cell

# %%
"""
import torch
import torch.nn as nn

class Decoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers, dropout):
        super(Decoder, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        # Embedding layer for decoder
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        # LSTM layer for decoder
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers, dropout=dropout)

        # Fully connected layer for output
        self.fc_out = nn.Linear(hidden_dim, vocab_size)

        # Dropout layer
        self.dropout = nn.Dropout(dropout)

    def init_hidden_state(self, batch_size, device):
        # Initialize the hidden state (h) and cell state (c) to zeros for multi-layer LSTM
        h_0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(device)
        c_0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(device)
        return h_0, c_0

    def forward(self, input, hidden, encoder_outputs=None):
        # Pass input through embedding layer
        embedded = self.dropout(self.embedding(input))

        # Pass through LSTM layer
        output, hidden = self.rnn(embedded, hidden)

        # Pass output through fully connected layer
        output = self.fc_out(output)

        return output, hidden
"""
# Out:
# '\nimport torch\nimport torch.nn as nn\n\nclass Decoder(nn.Module):\n    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers, dropout):\n        super(Decoder, self).__init__()\n        self.hidden_dim = hidden_dim\n        self.num_layers = num_layers\n\n        # Embedding layer for decoder\n        self.embedding = nn.Embedding(vocab_size, embedding_dim)\n\n        # LSTM layer for decoder\n        self.rnn = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers, dropout=dropout)\n\n        # Fully connected layer for output\n        self.fc_out = nn.Linear(hidden_dim, vocab_size)\n\n        # Dropout layer\n        self.dropout = nn.Dropout(dropout)\n\n    def init_hidden_state(self, batch_size, device):\n        # Initialize the hidden state (h) and cell state (c) to zeros for multi-layer LSTM\n        h_0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(device)\n        c_0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(device)\n        return h_0, c_0\n\n    def forward(self, input, hidden, encoder_outputs=None):\n        # Pass input through embedding layer\n        embedded = self.dropout(self.embedding(input))\n\n        # Pass through LSTM layer\n        output, hidden = self.rnn(embedded, hidden)\n\n        # Pass output through fully connected layer\n        output = self.fc_out(output)\n\n        return output, hidden\n'

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        assert (
            encoder.hidden_dim == decoder.hidden_dim
        ), "Hidden dimensions of encoder and decoder must be equal!"
        assert (
            encoder.n_layers == decoder.n_layers
        ), "Encoder and decoder must have equal number of layers!"

    def forward(self, src, trg, teacher_forcing_ratio):
        # src = [src length, batch size]
        # trg = [trg length, batch size]
        # teacher_forcing_ratio is probability to use teacher forcing
        # e.g. if teacher_forcing_ratio is 0.75 we use ground-truth inputs 75% of the time
        batch_size = trg.shape[1]
        trg_length = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        # tensor to store decoder outputs
        outputs = torch.zeros(trg_length, batch_size, trg_vocab_size).to(self.device)
        # last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src)
        # hidden = [n layers * n directions, batch size, hidden dim]
        # cell = [n layers * n directions, batch size, hidden dim]
        # first input to the decoder is the <sos> tokens
        input = trg[0, :]
        # input = [batch size]
        for t in range(1, trg_length):
            # insert input token embedding, previous hidden and previous cell states
            # receive output tensor (predictions) and new hidden and cell states
            output, hidden, cell = self.decoder(input, hidden, cell)
            # output = [batch size, output dim]
            # hidden = [n layers, batch size, hidden dim]
            # cell = [n layers, batch size, hidden dim]
            # place predictions in a tensor holding predictions for each token
            outputs[t] = output
            # decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio
            # get the highest predicted token from our predictions
            top1 = output.argmax(1)
            # if teacher forcing, use actual next token as next input
            # if not, use predicted token
            input = trg[t] if teacher_force else top1
            # input = [batch size]
        return outputs

# %%
input_dim = len(fr_vocab)
output_dim = len(en_vocab)
encoder_embedding_dim = 256
decoder_embedding_dim = 256
hidden_dim = 512
n_layers = 2
encoder_dropout = 0.5
decoder_dropout = 0.5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

encoder = Encoder(
    input_dim,
    encoder_embedding_dim,
    hidden_dim,
    n_layers,
    encoder_dropout,
)

decoder = Decoder(
    output_dim,
    decoder_embedding_dim,
    hidden_dim,
    n_layers,
    decoder_dropout,
)

model = Seq2Seq(encoder, decoder, device).to(device)
print(model)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(13285, 256)
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.5)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(8513, 256)
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.5)
#     (fc_out): Linear(in_features=512, out_features=8513, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        nn.init.uniform_(param.data, -0.08, 0.08)


model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(13285, 256)
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.5)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(8513, 256)
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.5)
#     (fc_out): Linear(in_features=512, out_features=8513, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


print(f"The model has {count_parameters(model):,} trainable parameters")
# Out:
# The model has 17,303,873 trainable parameters

# %%
optimizer = optim.Adam(model.parameters())

# %%
criterion = nn.CrossEntropyLoss(ignore_index=pad_index)

# %%
def train_fn(
    model, data_loader, optimizer, criterion, clip, teacher_forcing_ratio, device
):
    model.train()
    epoch_loss = 0
    for i, batch in enumerate(data_loader):
        src = batch["fr_ids"].to(device)
        trg = batch["en_ids"].to(device)
        # src = [src length, batch size]
        # trg = [trg length, batch size]
        optimizer.zero_grad()
        output = model(src, trg, teacher_forcing_ratio)
        # output = [trg length, batch size, trg vocab size]
        output_dim = output.shape[-1]
        output = output[1:].view(-1, output_dim)
        # output = [(trg length - 1) * batch size, trg vocab size]
        trg = trg[1:].view(-1)
        # trg = [(trg length - 1) * batch size]
        loss = criterion(output, trg)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        epoch_loss += loss.item()
    return epoch_loss / len(data_loader)

# %%
def evaluate_fn(model, data_loader, criterion, device):
    model.eval()
    epoch_loss = 0
    with torch.no_grad():
        for i, batch in enumerate(data_loader):
            src = batch["fr_ids"].to(device)
            trg = batch["en_ids"].to(device)
            # src = [src length, batch size]
            # trg = [trg length, batch size]
            output = model(src, trg, 0)  # turn off teacher forcing
            # output = [trg length, batch size, trg vocab size]
            output_dim = output.shape[-1]
            output = output[1:].view(-1, output_dim)
            # output = [(trg length - 1) * batch size, trg vocab size]
            trg = trg[1:].view(-1)
            # trg = [(trg length - 1) * batch size]
            loss = criterion(output, trg)
            epoch_loss += loss.item()
    return epoch_loss / len(data_loader)

# %%
n_epochs = 10
clip = 1.0
teacher_forcing_ratio = 0.5

best_valid_loss = float("inf")

for epoch in tqdm.tqdm(range(n_epochs)):

  start_time = time.time()

  train_loss = train_fn(
      model,
      train_data_loader,
      optimizer,
      criterion,
      clip,
      teacher_forcing_ratio,
      device,
  )
  valid_loss = evaluate_fn(
      model,
      valid_data_loader,
      criterion,
      device,
  )

  end_time = time.time()
  epoch_mins, epoch_secs = divmod(end_time - start_time, 60)

  if valid_loss < best_valid_loss:
      best_valid_loss = valid_loss
      torch.save(model.state_dict(), "/content/drive/MyDrive/Interview/seq2seq.pt")
  print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s', flush=True)
  print(f"\tTrain Loss: {train_loss:7.3f} | Train PPL: {np.exp(train_loss):7.3f}")
  print(f"\tValid Loss: {valid_loss:7.3f} | Valid PPL: {np.exp(valid_loss):7.3f}")
  # Additional print statement to show loss of each epoch
  print(f'Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Val Loss: {valid_loss:.3f}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 01 | Time: 3.0m 29.23480463027954s
#  10%|█         | 1/10 [03:33<31:58, 213.14s/it]
# 	Train Loss:   4.368 | Train PPL:  78.900
# 	Valid Loss:   3.998 | Valid PPL:  54.515
# Epoch: 01 | Train Loss: 4.368 | Val Loss: 3.998
# Epoch: 02 | Time: 3.0m 28.83294105529785s
#  20%|██        | 2/10 [07:02<28:05, 210.72s/it]
# 	Train Loss:   3.290 | Train PPL:  26.856
# 	Valid Loss:   3.338 | Valid PPL:  28.151
# Epoch: 02 | Train Loss: 3.290 | Val Loss: 3.338
# Epoch: 03 | Time: 3.0m 26.149043083190918s
#  30%|███       | 3/10 [10:28<24:21, 208.78s/it]
# 	Train Loss:   2.682 | Train PPL:  14.616
# 	Valid Loss:   2.861 | Valid PPL:  17.472
# Epoch: 03 | Train Loss: 2.682 | Val Loss: 2.861
# Epoch: 04 | Time: 3.0m 27.628522634506226s
#  40%|████      | 4/10 [13:56<20:50, 208.40s/it]
# 	Train Loss:   2.258 | Train PPL:   9.563
# 	Valid Loss:   2.589 | Valid PPL:  13.320
# Epoch: 04 | Train Loss: 2.258 | Val Loss: 2.589
# Epoch: 05 | Time: 3.0m 27.748502254486084s
#  50%|█████     | 5/10 [17:24<17:21, 208.23s/it]
# 	Train Loss:   1.954 | Train PPL:   7.056
# 	Valid Loss:   2.393 | Valid PPL:  10.946
# Epoch: 05 | Train Loss: 1.954 | Val Loss: 2.393
# Epoch: 06 | Time: 3.0m 36.78524613380432s
#  60%|██████    | 6/10 [21:01<14:04, 211.21s/it]
# 	Train Loss:   1.731 | Train PPL:   5.645
# 	Valid Loss:   2.288 | Valid PPL:   9.852
# Epoch: 06 | Train Loss: 1.731 | Val Loss: 2.288
# Epoch: 07 | Time: 3.0m 25.604087591171265s
#  70%|███████   | 7/10 [24:27<10:28, 209.45s/it]
# 	Train Loss:   1.553 | Train PPL:   4.726
# 	Valid Loss:   2.177 | Valid PPL:   8.819
# Epoch: 07 | Train Loss: 1.553 | Val Loss: 2.177
# Epoch: 08 | Time: 3.0m 25.952284574508667s
#  80%|████████  | 8/10 [27:53<06:56, 208.42s/it]
# 	Train Loss:   1.421 | Train PPL:   4.140
# 	Valid Loss:   2.124 | Valid PPL:   8.368
# Epoch: 08 | Train Loss: 1.421 | Val Loss: 2.124
# Epoch: 09 | Time: 3.0m 27.102211236953735s
#  90%|█████████ | 9/10 [31:20<03:28, 208.07s/it]
# 	Train Loss:   1.310 | Train PPL:   3.705
# 	Valid Loss:   2.065 | Valid PPL:   7.888
# Epoch: 09 | Train Loss: 1.310 | Val Loss: 2.065
# Epoch: 10 | Time: 3.0m 24.176708221435547s
# 100%|██████████| 10/10 [34:45<00:00, 208.52s/it]
# 	Train Loss:   1.212 | Train PPL:   3.362
# 	Valid Loss:   2.030 | Valid PPL:   7.615
# Epoch: 10 | Train Loss: 1.212 | Val Loss: 2.030

# %% [markdown]
# **Test Accuracy**

# %%
def evaluate_fn(model, data_loader, criterion, device):
    model.eval()  # Set the model to evaluation mode
    epoch_loss = 0
    correct_preds = 0
    total_preds = 0

    with torch.no_grad():  # No need to compute gradients during evaluation
        for batch in data_loader:
            src = batch["fr_ids"].to(device)  # French sentences
            trg = batch["en_ids"].to(device)  # English sentences (target)

            # Get model predictions
            output = model(src, trg, teacher_forcing_ratio=0)  # No teacher forcing during evaluation

            # Calculate the loss
            output_dim = output.shape[-1]
            output = output[1:].view(-1, output_dim)  # Remove <sos> token
            trg = trg[1:].view(-1)  # Remove <sos> token from target

            loss = criterion(output, trg)
            epoch_loss += loss.item()

            # Calculate accuracy
            pred = output.argmax(1)  # Get the index of the highest prediction
            correct_preds += (pred == trg).sum().item()
            total_preds += trg.size(0)

    return epoch_loss / len(data_loader), correct_preds / total_preds
test_loss, test_accuracy = evaluate_fn(model, test_data_loader, criterion, device)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Test Loss: 2.0223
# Test Accuracy: 26.04%

# %% [markdown]
# **Bleu, ROUGE, METEOR Score**

# %%
import nltk
nltk.download('wordnet')
from nltk.translate.bleu_score import corpus_bleu, sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer
import torch

# Function to calculate BLEU score
def calculate_bleu_score(references, hypotheses):
    return corpus_bleu(references, hypotheses)

# Function to calculate ROUGE score
def calculate_rouge_score(references, hypotheses):
    scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
    rouge_scores = []
    for ref, hyp in zip(references, hypotheses):
        # Ensure both are joined into strings of space-separated tokens
        ref_str = ' '.join(ref)  # Join reference tokens
        hyp_str = ' '.join(hyp)  # Join hypothesis tokens
        score = scorer.score(ref_str, hyp_str)
        rouge_scores.append({
            'rouge1': score['rouge1'].fmeasure,
            'rouge2': score['rouge2'].fmeasure,
            'rougeL': score['rougeL'].fmeasure
        })
    return rouge_scores

# Function to calculate METEOR score
def calculate_meteor_score(references, hypotheses):
    meteor_scores = []
    for ref, hyp in zip(references, hypotheses):
        meteor_scores.append(meteor_score([ref], hyp))
    return meteor_scores

# Define evaluation function for 10 samples
def evaluate_fn(model, data_loader, device, en_vocab, max_samples=10):
    model.eval()
    references = []
    hypotheses = []
    samples_processed = 0

    with torch.no_grad():
        for batch in data_loader:
            if samples_processed >= max_samples:
                break  # Stop after processing 10 samples

            src = batch["fr_ids"].to(device)
            trg = batch["en_ids"].to(device)
            output = model(src, trg, teacher_forcing_ratio=0)  # No teacher forcing during evaluation

            # Output contains [trg_length, batch_size, output_dim]
            # Get the predictions for each timestep
            for i in range(output.shape[1]):
                prediction = output[:, i, :].argmax(dim=1)

                # Lookup tokens for predicted and target sentences using en_vocab
                predicted_sentence = en_vocab.lookup_tokens(prediction.tolist())  # Convert IDs to words
                target_sentence = en_vocab.lookup_tokens(trg[:, i].tolist())  # Convert IDs to words

                hypotheses.append(predicted_sentence)
                references.append(target_sentence)  # No need to wrap in list here

                samples_processed += 1
                if samples_processed >= max_samples:
                    break  # Stop after processing the required number of samples

    # Calculate BLEU score
    bleu = calculate_bleu_score(references, hypotheses)

    # Calculate ROUGE score
    rouge = calculate_rouge_score(references, hypotheses)

    # Calculate METEOR score
    meteor = calculate_meteor_score(references, hypotheses)

    return bleu, rouge, meteor

# Example usage (with max_samples set to 10)
bleu_score, rouge_scores, meteor_score = evaluate_fn(model, test_data_loader, device, en_vocab, max_samples=10)

# Print the scores
print(f"BLEU score: {bleu_score}")
for i, rouge_score in enumerate(rouge_scores):
    print(f"ROUGE scores for sample {i + 1}: {rouge_score}")
print(f"METEOR scores: {meteor_score}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# BLEU score: 9.309480961664223e-232
# ROUGE scores for sample 1: {'rouge1': 0.38095238095238093, 'rouge2': 0.10000000000000002, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 2: {'rouge1': 0.24390243902439024, 'rouge2': 0.15384615384615385, 'rougeL': 0.24390243902439024}
# ROUGE scores for sample 3: {'rouge1': 0.2857142857142857, 'rouge2': 0.15, 'rougeL': 0.2857142857142857}
# ROUGE scores for sample 4: {'rouge1': 0.3181818181818182, 'rouge2': 0.14285714285714285, 'rougeL': 0.3181818181818182}
# ROUGE scores for sample 5: {'rouge1': 0.3333333333333333, 'rouge2': 0.3, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 6: {'rouge1': 0.14285714285714285, 'rouge2': 0.05000000000000001, 'rougeL': 0.14285714285714285}
# ROUGE scores for sample 7: {'rouge1': 0.1951219512195122, 'rouge2': 0.15384615384615385, 'rougeL': 0.1951219512195122}
# ROUGE scores for sample 8: {'rouge1': 0.19047619047619047, 'rouge2': 0.05000000000000001, 'rougeL': 0.19047619047619047}
# ROUGE scores for sample 9: {'rouge1': 0.2857142857142857, 'rouge2': 0.25, 'rougeL': 0.2857142857142857}
# ROUGE scores for sample 10: {'rouge1': 0.14285714285714285, 'rouge2': 0.05000000000000001, 'rougeL': 0.14285714285714285}
# METEOR scores: [0.3128507295173962, 0.23232323232323232, 0.21799628942486085, 0.1590909090909091, 0.36079545454545453, 0.1434659090909091, 0.20272727272727276, 0.1690909090909091, 0.3144712430426716, 0.1434659090909091]

# %%
import nltk
nltk.download('wordnet')
from nltk.translate.bleu_score import corpus_bleu, sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer
import torch

# Function to calculate BLEU score
def calculate_bleu_score(references, hypotheses):
    return corpus_bleu(references, hypotheses)

# Function to calculate ROUGE score
def calculate_rouge_score(references, hypotheses):
    scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
    rouge_scores = []
    for ref, hyp in zip(references, hypotheses):
        # Ensure both are joined into strings of space-separated tokens
        ref_str = ' '.join(ref)  # Join reference tokens
        hyp_str = ' '.join(hyp)  # Join hypothesis tokens
        score = scorer.score(ref_str, hyp_str)
        rouge_scores.append({
            'rouge1': score['rouge1'].fmeasure,
            'rouge2': score['rouge2'].fmeasure,
            'rougeL': score['rougeL'].fmeasure
        })
    return rouge_scores

# Function to calculate METEOR score
def calculate_meteor_score(references, hypotheses):
    meteor_scores = []
    for ref, hyp in zip(references, hypotheses):
        meteor_scores.append(meteor_score([ref], hyp))
    return meteor_scores

# Define evaluation function
def evaluate_fn(model, data_loader, device, en_vocab):
    model.eval()
    references = []
    hypotheses = []
    with torch.no_grad():
        for batch in data_loader:
            src = batch["fr_ids"].to(device)
            trg = batch["en_ids"].to(device)
            output = model(src, trg, teacher_forcing_ratio=0)  # No teacher forcing during evaluation

            # Output contains [trg_length, batch_size, output_dim]
            # Get the predictions for each timestep
            for i in range(output.shape[1]):
                prediction = output[:, i, :].argmax(dim=1)

                # Lookup tokens for predicted and target sentences using en_vocab
                predicted_sentence = en_vocab.lookup_tokens(prediction.tolist())  # Convert IDs to words
                target_sentence = en_vocab.lookup_tokens(trg[:, i].tolist())  # Convert IDs to words

                hypotheses.append(predicted_sentence)
                references.append(target_sentence)  # No need to wrap in list here

    # Calculate BLEU score
    bleu = calculate_bleu_score(references, hypotheses)

    # Calculate ROUGE score
    rouge = calculate_rouge_score(references, hypotheses)

    # Calculate METEOR score
    meteor = calculate_meteor_score(references, hypotheses)

    return bleu, rouge, meteor

# Example usage
bleu_score, rouge_scores, meteor_score = evaluate_fn(model, test_data_loader, device, en_vocab)

# Print the scores
print(f"BLEU score: {bleu_score}")
for i, rouge_score in enumerate(rouge_scores):
    print(f"ROUGE scores for sample {i + 1}: {rouge_score}")
print(f"METEOR scores: {meteor_score}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Streaming output truncated to the last 5000 lines.
# ROUGE scores for sample 12390: {'rouge1': 0.34782608695652173, 'rouge2': 0.2727272727272727, 'rougeL': 0.34782608695652173}
# ROUGE scores for sample 12391: {'rouge1': 0.21739130434782608, 'rouge2': 0.18181818181818182, 'rougeL': 0.21739130434782608}
# ROUGE scores for sample 12392: {'rouge1': 0.17391304347826086, 'rouge2': 0.09090909090909091, 'rougeL': 0.17391304347826086}
# ROUGE scores for sample 12393: {'rouge1': 0.2608695652173913, 'rouge2': 0.22727272727272727, 'rougeL': 0.2608695652173913}
# ROUGE scores for sample 12394: {'rouge1': 0.2608695652173913, 'rouge2': 0.22727272727272727, 'rougeL': 0.2608695652173913}
# ROUGE scores for sample 12395: {'rouge1': 0.2608695652173913, 'rouge2': 0.09090909090909091, 'rougeL': 0.21739130434782608}
# ROUGE scores for sample 12396: {'rouge1': 0.13043478260869565, 'rouge2': 0.045454545454545456, 'rougeL': 0.13043478260869565}
# ROUGE scores for sample 12397: {'rouge1': 0.2608695652173913, 'rouge2': 0.18181818181818182, 'rougeL': 0.2608695652173913}
# ROUGE scores for sample 12398: {'rouge1': 0.3555555555555555, 'rouge2': 0.23255813953488372, 'rougeL': 0.3555555555555555}
# ROUGE scores for sample 12399: {'rouge1': 0.17777777777777776, 'rouge2': 0.046511627906976744, 'rougeL': 0.17777777777777776}
# ROUGE scores for sample 12400: {'rouge1': 0.21739130434782608, 'rouge2': 0.09090909090909091, 'rougeL': 0.17391304347826086}
# ROUGE scores for sample 12401: {'rouge1': 0.17391304347826086, 'rouge2': 0.09090909090909091, 'rougeL': 0.17391304347826086}
# ROUGE scores for sample 12402: {'rouge1': 0.13043478260869565, 'rouge2': 0.0, 'rougeL': 0.13043478260869565}
# ROUGE scores for sample 12403: {'rouge1': 0.391304347826087, 'rouge2': 0.36363636363636365, 'rougeL': 0.391304347826087}
# ROUGE scores for sample 12404: {'rouge1': 0.2666666666666666, 'rouge2': 0.18604651162790697, 'rougeL': 0.2666666666666666}
# ROUGE scores for sample 12405: {'rouge1': 0.30434782608695654, 'rouge2': 0.18181818181818182, 'rougeL': 0.30434782608695654}
# ROUGE scores for sample 12406: {'rouge1': 0.4782608695652174, 'rouge2': 0.4090909090909091, 'rougeL': 0.4782608695652174}
# ROUGE scores for sample 12407: {'rouge1': 0.375, 'rouge2': 0.30434782608695654, 'rougeL': 0.375}
# ROUGE scores for sample 12408: {'rouge1': 0.13043478260869565, 'rouge2': 0.09090909090909091, 'rougeL': 0.13043478260869565}
# ROUGE scores for sample 12409: {'rouge1': 0.17777777777777776, 'rouge2': 0.0, 'rougeL': 0.1333333333333333}
# ROUGE scores for sample 12410: {'rouge1': 0.17391304347826086, 'rouge2': 0.045454545454545456, 'rougeL': 0.13043478260869565}
# ROUGE scores for sample 12411: {'rouge1': 0.17391304347826086, 'rouge2': 0.13636363636363635, 'rougeL': 0.17391304347826086}
# ROUGE scores for sample 12412: {'rouge1': 0.34782608695652173, 'rouge2': 0.3181818181818182, 'rougeL': 0.34782608695652173}
# ROUGE scores for sample 12413: {'rouge1': 0.34782608695652173, 'rouge2': 0.22727272727272727, 'rougeL': 0.34782608695652173}
# ROUGE scores for sample 12414: {'rouge1': 0.22222222222222224, 'rouge2': 0.046511627906976744, 'rougeL': 0.17777777777777776}
# ROUGE scores for sample 12415: {'rouge1': 0.17391304347826086, 'rouge2': 0.045454545454545456, 'rougeL': 0.17391304347826086}
# ROUGE scores for sample 12416: {'rouge1': 0.2666666666666666, 'rouge2': 0.046511627906976744, 'rougeL': 0.22222222222222224}
# ROUGE scores for sample 12417: {'rouge1': 0.20000000000000004, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12418: {'rouge1': 0.4000000000000001, 'rouge2': 0.3157894736842105, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12419: {'rouge1': 0.35, 'rouge2': 0.2631578947368421, 'rougeL': 0.35}
# ROUGE scores for sample 12420: {'rouge1': 0.35, 'rouge2': 0.3157894736842105, 'rougeL': 0.35}
# ROUGE scores for sample 12421: {'rouge1': 0.3, 'rouge2': 0.21052631578947367, 'rougeL': 0.3}
# ROUGE scores for sample 12422: {'rouge1': 0.38095238095238093, 'rouge2': 0.3, 'rougeL': 0.38095238095238093}
# ROUGE scores for sample 12423: {'rouge1': 0.35, 'rouge2': 0.2631578947368421, 'rougeL': 0.35}
# ROUGE scores for sample 12424: {'rouge1': 0.45, 'rouge2': 0.42105263157894735, 'rougeL': 0.45}
# ROUGE scores for sample 12425: {'rouge1': 0.35, 'rouge2': 0.3157894736842105, 'rougeL': 0.35}
# ROUGE scores for sample 12426: {'rouge1': 0.25641025641025644, 'rouge2': 0.05405405405405406, 'rougeL': 0.25641025641025644}
# ROUGE scores for sample 12427: {'rouge1': 0.25, 'rouge2': 0.05263157894736842, 'rougeL': 0.25}
# ROUGE scores for sample 12428: {'rouge1': 0.38095238095238093, 'rouge2': 0.3, 'rougeL': 0.38095238095238093}
# ROUGE scores for sample 12429: {'rouge1': 0.3157894736842105, 'rouge2': 0.16666666666666666, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12430: {'rouge1': 0.20000000000000004, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12431: {'rouge1': 0.3, 'rouge2': 0.2631578947368421, 'rougeL': 0.3}
# ROUGE scores for sample 12432: {'rouge1': 0.3, 'rouge2': 0.21052631578947367, 'rougeL': 0.3}
# ROUGE scores for sample 12433: {'rouge1': 0.3333333333333333, 'rouge2': 0.20000000000000004, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 12434: {'rouge1': 0.20000000000000004, 'rouge2': 0.0, 'rougeL': 0.15}
# ROUGE scores for sample 12435: {'rouge1': 0.4000000000000001, 'rouge2': 0.2631578947368421, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12436: {'rouge1': 0.20000000000000004, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12437: {'rouge1': 0.25, 'rouge2': 0.15789473684210525, 'rougeL': 0.25}
# ROUGE scores for sample 12438: {'rouge1': 0.15, 'rouge2': 0.05263157894736842, 'rougeL': 0.15}
# ROUGE scores for sample 12439: {'rouge1': 0.45, 'rouge2': 0.3684210526315789, 'rougeL': 0.45}
# ROUGE scores for sample 12440: {'rouge1': 0.3, 'rouge2': 0.15789473684210525, 'rougeL': 0.3}
# ROUGE scores for sample 12441: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12442: {'rouge1': 0.4000000000000001, 'rouge2': 0.2631578947368421, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12443: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12444: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12445: {'rouge1': 0.3, 'rouge2': 0.15789473684210525, 'rougeL': 0.3}
# ROUGE scores for sample 12446: {'rouge1': 0.2857142857142857, 'rouge2': 0.10000000000000002, 'rougeL': 0.23809523809523808}
# ROUGE scores for sample 12447: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12448: {'rouge1': 0.3, 'rouge2': 0.21052631578947367, 'rougeL': 0.3}
# ROUGE scores for sample 12449: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12450: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12451: {'rouge1': 0.15, 'rouge2': 0.0, 'rougeL': 0.15}
# ROUGE scores for sample 12452: {'rouge1': 0.15, 'rouge2': 0.10526315789473684, 'rougeL': 0.15}
# ROUGE scores for sample 12453: {'rouge1': 0.3157894736842105, 'rouge2': 0.1111111111111111, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12454: {'rouge1': 0.20000000000000004, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12455: {'rouge1': 0.25, 'rouge2': 0.10526315789473684, 'rougeL': 0.25}
# ROUGE scores for sample 12456: {'rouge1': 0.25, 'rouge2': 0.15789473684210525, 'rougeL': 0.25}
# ROUGE scores for sample 12457: {'rouge1': 0.25, 'rouge2': 0.10526315789473684, 'rougeL': 0.25}
# ROUGE scores for sample 12458: {'rouge1': 0.35, 'rouge2': 0.21052631578947367, 'rougeL': 0.35}
# ROUGE scores for sample 12459: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12460: {'rouge1': 0.3333333333333333, 'rouge2': 0.25, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 12461: {'rouge1': 0.2857142857142857, 'rouge2': 0.15, 'rougeL': 0.2857142857142857}
# ROUGE scores for sample 12462: {'rouge1': 0.15, 'rouge2': 0.0, 'rougeL': 0.15}
# ROUGE scores for sample 12463: {'rouge1': 0.15, 'rouge2': 0.0, 'rougeL': 0.15}
# ROUGE scores for sample 12464: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12465: {'rouge1': 0.3076923076923077, 'rouge2': 0.21621621621621623, 'rougeL': 0.3076923076923077}
# ROUGE scores for sample 12466: {'rouge1': 0.25, 'rouge2': 0.15789473684210525, 'rougeL': 0.25}
# ROUGE scores for sample 12467: {'rouge1': 0.14634146341463414, 'rouge2': 0.05128205128205128, 'rougeL': 0.14634146341463414}
# ROUGE scores for sample 12468: {'rouge1': 0.25, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12469: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12470: {'rouge1': 0.3, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12471: {'rouge1': 0.35, 'rouge2': 0.3157894736842105, 'rougeL': 0.35}
# ROUGE scores for sample 12472: {'rouge1': 0.35, 'rouge2': 0.2631578947368421, 'rougeL': 0.35}
# ROUGE scores for sample 12473: {'rouge1': 0.3, 'rouge2': 0.21052631578947367, 'rougeL': 0.3}
# ROUGE scores for sample 12474: {'rouge1': 0.25, 'rouge2': 0.15789473684210525, 'rougeL': 0.25}
# ROUGE scores for sample 12475: {'rouge1': 0.41025641025641024, 'rouge2': 0.3243243243243243, 'rougeL': 0.41025641025641024}
# ROUGE scores for sample 12476: {'rouge1': 0.25, 'rouge2': 0.05263157894736842, 'rougeL': 0.25}
# ROUGE scores for sample 12477: {'rouge1': 0.1951219512195122, 'rouge2': 0.10256410256410256, 'rougeL': 0.1951219512195122}
# ROUGE scores for sample 12478: {'rouge1': 0.5365853658536585, 'rouge2': 0.46153846153846156, 'rougeL': 0.5365853658536585}
# ROUGE scores for sample 12479: {'rouge1': 0.45, 'rouge2': 0.42105263157894735, 'rougeL': 0.45}
# ROUGE scores for sample 12480: {'rouge1': 0.3, 'rouge2': 0.2631578947368421, 'rougeL': 0.3}
# ROUGE scores for sample 12481: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12482: {'rouge1': 0.2857142857142857, 'rouge2': 0.15, 'rougeL': 0.2857142857142857}
# ROUGE scores for sample 12483: {'rouge1': 0.3, 'rouge2': 0.2631578947368421, 'rougeL': 0.3}
# ROUGE scores for sample 12484: {'rouge1': 0.25, 'rouge2': 0.10526315789473684, 'rougeL': 0.25}
# ROUGE scores for sample 12485: {'rouge1': 0.20000000000000004, 'rouge2': 0.15789473684210525, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12486: {'rouge1': 0.10000000000000002, 'rouge2': 0.0, 'rougeL': 0.10000000000000002}
# ROUGE scores for sample 12487: {'rouge1': 0.10000000000000002, 'rouge2': 0.0, 'rougeL': 0.10000000000000002}
# ROUGE scores for sample 12488: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12489: {'rouge1': 0.15384615384615385, 'rouge2': 0.10810810810810811, 'rougeL': 0.15384615384615385}
# ROUGE scores for sample 12490: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12491: {'rouge1': 0.20000000000000004, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12492: {'rouge1': 0.4000000000000001, 'rouge2': 0.3157894736842105, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12493: {'rouge1': 0.3, 'rouge2': 0.2631578947368421, 'rougeL': 0.3}
# ROUGE scores for sample 12494: {'rouge1': 0.05000000000000001, 'rouge2': 0.0, 'rougeL': 0.05000000000000001}
# ROUGE scores for sample 12495: {'rouge1': 0.25, 'rouge2': 0.10526315789473684, 'rougeL': 0.25}
# ROUGE scores for sample 12496: {'rouge1': 0.15, 'rouge2': 0.0, 'rougeL': 0.10000000000000002}
# ROUGE scores for sample 12497: {'rouge1': 0.15, 'rouge2': 0.05263157894736842, 'rougeL': 0.15}
# ROUGE scores for sample 12498: {'rouge1': 0.3, 'rouge2': 0.15789473684210525, 'rougeL': 0.3}
# ROUGE scores for sample 12499: {'rouge1': 0.4000000000000001, 'rouge2': 0.3684210526315789, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12500: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.15}
# ROUGE scores for sample 12501: {'rouge1': 0.3, 'rouge2': 0.2631578947368421, 'rougeL': 0.3}
# ROUGE scores for sample 12502: {'rouge1': 0.5714285714285714, 'rouge2': 0.4000000000000001, 'rougeL': 0.5714285714285714}
# ROUGE scores for sample 12503: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12504: {'rouge1': 0.20000000000000004, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12505: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.15}
# ROUGE scores for sample 12506: {'rouge1': 0.15, 'rouge2': 0.05263157894736842, 'rougeL': 0.15}
# ROUGE scores for sample 12507: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12508: {'rouge1': 0.35, 'rouge2': 0.21052631578947367, 'rougeL': 0.35}
# ROUGE scores for sample 12509: {'rouge1': 0.15384615384615385, 'rouge2': 0.10810810810810811, 'rougeL': 0.15384615384615385}
# ROUGE scores for sample 12510: {'rouge1': 0.25, 'rouge2': 0.10526315789473684, 'rougeL': 0.25}
# ROUGE scores for sample 12511: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12512: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12513: {'rouge1': 0.2926829268292683, 'rouge2': 0.15384615384615385, 'rougeL': 0.2926829268292683}
# ROUGE scores for sample 12514: {'rouge1': 0.5238095238095238, 'rouge2': 0.45, 'rougeL': 0.5238095238095238}
# ROUGE scores for sample 12515: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12516: {'rouge1': 0.25, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12517: {'rouge1': 0.45161290322580644, 'rouge2': 0.20689655172413796, 'rougeL': 0.45161290322580644}
# ROUGE scores for sample 12518: {'rouge1': 0.3, 'rouge2': 0.05263157894736842, 'rougeL': 0.3}
# ROUGE scores for sample 12519: {'rouge1': 0.3, 'rouge2': 0.2631578947368421, 'rougeL': 0.3}
# ROUGE scores for sample 12520: {'rouge1': 0.25, 'rouge2': 0.0, 'rougeL': 0.25}
# ROUGE scores for sample 12521: {'rouge1': 0.15, 'rouge2': 0.0, 'rougeL': 0.15}
# ROUGE scores for sample 12522: {'rouge1': 0.14634146341463414, 'rouge2': 0.0, 'rougeL': 0.14634146341463414}
# ROUGE scores for sample 12523: {'rouge1': 0.10000000000000002, 'rouge2': 0.0, 'rougeL': 0.10000000000000002}
# ROUGE scores for sample 12524: {'rouge1': 0.4000000000000001, 'rouge2': 0.3684210526315789, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12525: {'rouge1': 0.45, 'rouge2': 0.3684210526315789, 'rougeL': 0.45}
# ROUGE scores for sample 12526: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12527: {'rouge1': 0.35, 'rouge2': 0.15789473684210525, 'rougeL': 0.3}
# ROUGE scores for sample 12528: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12529: {'rouge1': 0.4000000000000001, 'rouge2': 0.3684210526315789, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12530: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12531: {'rouge1': 0.20000000000000004, 'rouge2': 0.15789473684210525, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12532: {'rouge1': 0.36842105263157887, 'rouge2': 0.0, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12533: {'rouge1': 0.3333333333333333, 'rouge2': 0.3, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 12534: {'rouge1': 0.3, 'rouge2': 0.21052631578947367, 'rougeL': 0.3}
# ROUGE scores for sample 12535: {'rouge1': 0.5714285714285714, 'rouge2': 0.45, 'rougeL': 0.5714285714285714}
# ROUGE scores for sample 12536: {'rouge1': 0.25641025641025644, 'rouge2': 0.16216216216216214, 'rougeL': 0.25641025641025644}
# ROUGE scores for sample 12537: {'rouge1': 0.25, 'rouge2': 0.15789473684210525, 'rougeL': 0.25}
# ROUGE scores for sample 12538: {'rouge1': 0.0975609756097561, 'rouge2': 0.0, 'rougeL': 0.0975609756097561}
# ROUGE scores for sample 12539: {'rouge1': 0.10256410256410256, 'rouge2': 0.0, 'rougeL': 0.10256410256410256}
# ROUGE scores for sample 12540: {'rouge1': 0.20000000000000004, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12541: {'rouge1': 0.35, 'rouge2': 0.15789473684210525, 'rougeL': 0.3}
# ROUGE scores for sample 12542: {'rouge1': 0.3, 'rouge2': 0.21052631578947367, 'rougeL': 0.3}
# ROUGE scores for sample 12543: {'rouge1': 0.15, 'rouge2': 0.0, 'rougeL': 0.15}
# ROUGE scores for sample 12544: {'rouge1': 0.3, 'rouge2': 0.21052631578947367, 'rougeL': 0.3}
# ROUGE scores for sample 12545: {'rouge1': 0.42424242424242425, 'rouge2': 0.2580645161290323, 'rougeL': 0.42424242424242425}
# ROUGE scores for sample 12546: {'rouge1': 0.35294117647058826, 'rouge2': 0.25, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12547: {'rouge1': 0.631578947368421, 'rouge2': 0.6111111111111112, 'rougeL': 0.631578947368421}
# ROUGE scores for sample 12548: {'rouge1': 0.24242424242424243, 'rouge2': 0.12903225806451615, 'rougeL': 0.24242424242424243}
# ROUGE scores for sample 12549: {'rouge1': 0.47058823529411764, 'rouge2': 0.375, 'rougeL': 0.47058823529411764}
# ROUGE scores for sample 12550: {'rouge1': 0.11764705882352941, 'rouge2': 0.0, 'rougeL': 0.11764705882352941}
# ROUGE scores for sample 12551: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12552: {'rouge1': 0.11764705882352941, 'rouge2': 0.0, 'rougeL': 0.11764705882352941}
# ROUGE scores for sample 12553: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12554: {'rouge1': 0.29411764705882354, 'rouge2': 0.125, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12555: {'rouge1': 0.35294117647058826, 'rouge2': 0.0, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12556: {'rouge1': 0.5294117647058824, 'rouge2': 0.375, 'rougeL': 0.5294117647058824}
# ROUGE scores for sample 12557: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12558: {'rouge1': 0.5294117647058824, 'rouge2': 0.5, 'rougeL': 0.5294117647058824}
# ROUGE scores for sample 12559: {'rouge1': 0.38709677419354843, 'rouge2': 0.20689655172413796, 'rougeL': 0.38709677419354843}
# ROUGE scores for sample 12560: {'rouge1': 0.11764705882352941, 'rouge2': 0.0, 'rougeL': 0.11764705882352941}
# ROUGE scores for sample 12561: {'rouge1': 0.35294117647058826, 'rouge2': 0.25, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12562: {'rouge1': 0.5294117647058824, 'rouge2': 0.4375, 'rougeL': 0.5294117647058824}
# ROUGE scores for sample 12563: {'rouge1': 0.3888888888888889, 'rouge2': 0.35294117647058826, 'rougeL': 0.3888888888888889}
# ROUGE scores for sample 12564: {'rouge1': 0.6470588235294118, 'rouge2': 0.625, 'rougeL': 0.6470588235294118}
# ROUGE scores for sample 12565: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12566: {'rouge1': 0.47058823529411764, 'rouge2': 0.4375, 'rougeL': 0.47058823529411764}
# ROUGE scores for sample 12567: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12568: {'rouge1': 0.29411764705882354, 'rouge2': 0.25, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12569: {'rouge1': 0.5, 'rouge2': 0.4000000000000001, 'rougeL': 0.5}
# ROUGE scores for sample 12570: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12571: {'rouge1': 0.23529411764705882, 'rouge2': 0.1875, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12572: {'rouge1': 0.43749999999999994, 'rouge2': 0.0, 'rougeL': 0.37500000000000006}
# ROUGE scores for sample 12573: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12574: {'rouge1': 0.23529411764705882, 'rouge2': 0.0625, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12575: {'rouge1': 0.29411764705882354, 'rouge2': 0.125, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12576: {'rouge1': 0.058823529411764705, 'rouge2': 0.0, 'rougeL': 0.058823529411764705}
# ROUGE scores for sample 12577: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12578: {'rouge1': 0.4117647058823529, 'rouge2': 0.375, 'rougeL': 0.4117647058823529}
# ROUGE scores for sample 12579: {'rouge1': 0.30303030303030304, 'rouge2': 0.19354838709677422, 'rougeL': 0.30303030303030304}
# ROUGE scores for sample 12580: {'rouge1': 0.17647058823529413, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12581: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12582: {'rouge1': 0.17647058823529413, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12583: {'rouge1': 0.29411764705882354, 'rouge2': 0.25, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12584: {'rouge1': 0.23529411764705882, 'rouge2': 0.0, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12585: {'rouge1': 0.4117647058823529, 'rouge2': 0.375, 'rougeL': 0.4117647058823529}
# ROUGE scores for sample 12586: {'rouge1': 0.4444444444444444, 'rouge2': 0.35294117647058826, 'rougeL': 0.4444444444444444}
# ROUGE scores for sample 12587: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12588: {'rouge1': 0.29411764705882354, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12589: {'rouge1': 0.4117647058823529, 'rouge2': 0.375, 'rougeL': 0.4117647058823529}
# ROUGE scores for sample 12590: {'rouge1': 0.35294117647058826, 'rouge2': 0.25, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12591: {'rouge1': 0.29411764705882354, 'rouge2': 0.125, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12592: {'rouge1': 0.2222222222222222, 'rouge2': 0.058823529411764705, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 12593: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12594: {'rouge1': 0.5555555555555556, 'rouge2': 0.4117647058823529, 'rougeL': 0.5555555555555556}
# ROUGE scores for sample 12595: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12596: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12597: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12598: {'rouge1': 0.17647058823529413, 'rouge2': 0.0, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12599: {'rouge1': 0.11428571428571428, 'rouge2': 0.06060606060606061, 'rougeL': 0.11428571428571428}
# ROUGE scores for sample 12600: {'rouge1': 0.17647058823529413, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12601: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12602: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12603: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12604: {'rouge1': 0.17647058823529413, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12605: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12606: {'rouge1': 0.058823529411764705, 'rouge2': 0.0, 'rougeL': 0.058823529411764705}
# ROUGE scores for sample 12607: {'rouge1': 0.3333333333333333, 'rouge2': 0.11764705882352941, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 12608: {'rouge1': 0.17647058823529413, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12609: {'rouge1': 0.47058823529411764, 'rouge2': 0.375, 'rougeL': 0.47058823529411764}
# ROUGE scores for sample 12610: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12611: {'rouge1': 0.058823529411764705, 'rouge2': 0.0, 'rougeL': 0.058823529411764705}
# ROUGE scores for sample 12612: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12613: {'rouge1': 0.23529411764705882, 'rouge2': 0.0625, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12614: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12615: {'rouge1': 0.17647058823529413, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12616: {'rouge1': 0.3888888888888889, 'rouge2': 0.29411764705882354, 'rougeL': 0.3888888888888889}
# ROUGE scores for sample 12617: {'rouge1': 0.5882352941176471, 'rouge2': 0.4375, 'rougeL': 0.5882352941176471}
# ROUGE scores for sample 12618: {'rouge1': 0.29411764705882354, 'rouge2': 0.25, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12619: {'rouge1': 0.39999999999999997, 'rouge2': 0.24242424242424243, 'rougeL': 0.39999999999999997}
# ROUGE scores for sample 12620: {'rouge1': 0.5555555555555556, 'rouge2': 0.5294117647058824, 'rougeL': 0.5555555555555556}
# ROUGE scores for sample 12621: {'rouge1': 0.35294117647058826, 'rouge2': 0.25, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12622: {'rouge1': 0.30303030303030304, 'rouge2': 0.19354838709677422, 'rougeL': 0.30303030303030304}
# ROUGE scores for sample 12623: {'rouge1': 0.4117647058823529, 'rouge2': 0.25, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12624: {'rouge1': 0.23529411764705882, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12625: {'rouge1': 0.5625, 'rouge2': 0.13333333333333333, 'rougeL': 0.4375}
# ROUGE scores for sample 12626: {'rouge1': 0.23529411764705882, 'rouge2': 0.0, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12627: {'rouge1': 0.29411764705882354, 'rouge2': 0.125, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12628: {'rouge1': 0.4117647058823529, 'rouge2': 0.375, 'rougeL': 0.4117647058823529}
# ROUGE scores for sample 12629: {'rouge1': 0.29411764705882354, 'rouge2': 0.0625, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12630: {'rouge1': 0.24242424242424243, 'rouge2': 0.12903225806451615, 'rougeL': 0.24242424242424243}
# ROUGE scores for sample 12631: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12632: {'rouge1': 0.35294117647058826, 'rouge2': 0.125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12633: {'rouge1': 0.23529411764705882, 'rouge2': 0.0625, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12634: {'rouge1': 0.17647058823529413, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12635: {'rouge1': 0.1818181818181818, 'rouge2': 0.0, 'rougeL': 0.1818181818181818}
# ROUGE scores for sample 12636: {'rouge1': 0.23529411764705882, 'rouge2': 0.0625, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12637: {'rouge1': 0.4444444444444444, 'rouge2': 0.23529411764705882, 'rougeL': 0.4444444444444444}
# ROUGE scores for sample 12638: {'rouge1': 0.5, 'rouge2': 0.47058823529411764, 'rougeL': 0.5}
# ROUGE scores for sample 12639: {'rouge1': 0.17647058823529413, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12640: {'rouge1': 0.5882352941176471, 'rouge2': 0.4375, 'rougeL': 0.5882352941176471}
# ROUGE scores for sample 12641: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12642: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12643: {'rouge1': 0.47058823529411764, 'rouge2': 0.375, 'rougeL': 0.47058823529411764}
# ROUGE scores for sample 12644: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12645: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12646: {'rouge1': 0.47058823529411764, 'rouge2': 0.375, 'rougeL': 0.47058823529411764}
# ROUGE scores for sample 12647: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12648: {'rouge1': 0.5, 'rouge2': 0.3333333333333333, 'rougeL': 0.5}
# ROUGE scores for sample 12649: {'rouge1': 0.1818181818181818, 'rouge2': 0.06451612903225808, 'rougeL': 0.1818181818181818}
# ROUGE scores for sample 12650: {'rouge1': 0.35294117647058826, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12651: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12652: {'rouge1': 0.47058823529411764, 'rouge2': 0.1875, 'rougeL': 0.4117647058823529}
# ROUGE scores for sample 12653: {'rouge1': 0.23529411764705882, 'rouge2': 0.0, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12654: {'rouge1': 0.4117647058823529, 'rouge2': 0.25, 'rougeL': 0.4117647058823529}
# ROUGE scores for sample 12655: {'rouge1': 0.5454545454545455, 'rouge2': 0.5161290322580646, 'rougeL': 0.5454545454545455}
# ROUGE scores for sample 12656: {'rouge1': 0.30303030303030304, 'rouge2': 0.12903225806451615, 'rougeL': 0.24242424242424243}
# ROUGE scores for sample 12657: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12658: {'rouge1': 0.47058823529411764, 'rouge2': 0.375, 'rougeL': 0.47058823529411764}
# ROUGE scores for sample 12659: {'rouge1': 0.17142857142857143, 'rouge2': 0.06060606060606061, 'rougeL': 0.17142857142857143}
# ROUGE scores for sample 12660: {'rouge1': 0.3888888888888889, 'rouge2': 0.29411764705882354, 'rougeL': 0.3888888888888889}
# ROUGE scores for sample 12661: {'rouge1': 0.5, 'rouge2': 0.47058823529411764, 'rougeL': 0.5}
# ROUGE scores for sample 12662: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12663: {'rouge1': 0.28571428571428575, 'rouge2': 0.1818181818181818, 'rougeL': 0.28571428571428575}
# ROUGE scores for sample 12664: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12665: {'rouge1': 0.35294117647058826, 'rouge2': 0.25, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12666: {'rouge1': 0.17647058823529413, 'rouge2': 0.0625, 'rougeL': 0.17647058823529413}
# ROUGE scores for sample 12667: {'rouge1': 0.23529411764705882, 'rouge2': 0.1875, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12668: {'rouge1': 0.23529411764705882, 'rouge2': 0.125, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 12669: {'rouge1': 0.35294117647058826, 'rouge2': 0.3125, 'rougeL': 0.35294117647058826}
# ROUGE scores for sample 12670: {'rouge1': 0.47058823529411764, 'rouge2': 0.25, 'rougeL': 0.47058823529411764}
# ROUGE scores for sample 12671: {'rouge1': 0.5294117647058824, 'rouge2': 0.5, 'rougeL': 0.5294117647058824}
# ROUGE scores for sample 12672: {'rouge1': 0.35294117647058826, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 12673: {'rouge1': 0.3076923076923077, 'rouge2': 0.16216216216216214, 'rougeL': 0.3076923076923077}
# ROUGE scores for sample 12674: {'rouge1': 0.41025641025641024, 'rouge2': 0.16216216216216214, 'rougeL': 0.358974358974359}
# ROUGE scores for sample 12675: {'rouge1': 0.10526315789473684, 'rouge2': 0.0, 'rougeL': 0.10526315789473684}
# ROUGE scores for sample 12676: {'rouge1': 0.4117647058823529, 'rouge2': 0.3125, 'rougeL': 0.4117647058823529}
# ROUGE scores for sample 12677: {'rouge1': 0.15789473684210525, 'rouge2': 0.05555555555555555, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12678: {'rouge1': 0.3684210526315789, 'rouge2': 0.2777777777777778, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12679: {'rouge1': 0.35, 'rouge2': 0.21052631578947367, 'rougeL': 0.35}
# ROUGE scores for sample 12680: {'rouge1': 0.05405405405405406, 'rouge2': 0.0, 'rougeL': 0.05405405405405406}
# ROUGE scores for sample 12681: {'rouge1': 0.4000000000000001, 'rouge2': 0.3157894736842105, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12682: {'rouge1': 0.27027027027027023, 'rouge2': 0.05714285714285714, 'rougeL': 0.21621621621621623}
# ROUGE scores for sample 12683: {'rouge1': 0.21052631578947367, 'rouge2': 0.05555555555555555, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12684: {'rouge1': 0.21052631578947367, 'rouge2': 0.05555555555555555, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12685: {'rouge1': 0.21052631578947367, 'rouge2': 0.16666666666666666, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12686: {'rouge1': 0.15789473684210525, 'rouge2': 0.0, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12687: {'rouge1': 0.2631578947368421, 'rouge2': 0.16666666666666666, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12688: {'rouge1': 0.47368421052631576, 'rouge2': 0.4444444444444444, 'rougeL': 0.47368421052631576}
# ROUGE scores for sample 12689: {'rouge1': 0.45, 'rouge2': 0.42105263157894735, 'rougeL': 0.45}
# ROUGE scores for sample 12690: {'rouge1': 0.4000000000000001, 'rouge2': 0.3157894736842105, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12691: {'rouge1': 0.3157894736842105, 'rouge2': 0.05555555555555555, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12692: {'rouge1': 0.3157894736842105, 'rouge2': 0.2777777777777778, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12693: {'rouge1': 0.2631578947368421, 'rouge2': 0.2222222222222222, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12694: {'rouge1': 0.3157894736842105, 'rouge2': 0.16666666666666666, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12695: {'rouge1': 0.3157894736842105, 'rouge2': 0.2777777777777778, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12696: {'rouge1': 0.27027027027027023, 'rouge2': 0.17142857142857143, 'rougeL': 0.27027027027027023}
# ROUGE scores for sample 12697: {'rouge1': 0.3157894736842105, 'rouge2': 0.2222222222222222, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12698: {'rouge1': 0.3684210526315789, 'rouge2': 0.3333333333333333, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12699: {'rouge1': 0.21052631578947367, 'rouge2': 0.1111111111111111, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12700: {'rouge1': 0.21052631578947367, 'rouge2': 0.0, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12701: {'rouge1': 0.2631578947368421, 'rouge2': 0.16666666666666666, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12702: {'rouge1': 0.25, 'rouge2': 0.15789473684210525, 'rougeL': 0.25}
# ROUGE scores for sample 12703: {'rouge1': 0.2222222222222222, 'rouge2': 0.0, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 12704: {'rouge1': 0.3243243243243243, 'rouge2': 0.22857142857142856, 'rougeL': 0.3243243243243243}
# ROUGE scores for sample 12705: {'rouge1': 0.3157894736842105, 'rouge2': 0.2777777777777778, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12706: {'rouge1': 0.3684210526315789, 'rouge2': 0.1111111111111111, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12707: {'rouge1': 0.3684210526315789, 'rouge2': 0.05555555555555555, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12708: {'rouge1': 0.21621621621621623, 'rouge2': 0.05714285714285714, 'rougeL': 0.21621621621621623}
# ROUGE scores for sample 12709: {'rouge1': 0.3684210526315789, 'rouge2': 0.3333333333333333, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12710: {'rouge1': 0.35, 'rouge2': 0.21052631578947367, 'rougeL': 0.35}
# ROUGE scores for sample 12711: {'rouge1': 0.47368421052631576, 'rouge2': 0.4444444444444444, 'rougeL': 0.47368421052631576}
# ROUGE scores for sample 12712: {'rouge1': 0.3684210526315789, 'rouge2': 0.3333333333333333, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12713: {'rouge1': 0.21052631578947367, 'rouge2': 0.1111111111111111, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12714: {'rouge1': 0.35, 'rouge2': 0.15789473684210525, 'rougeL': 0.3}
# ROUGE scores for sample 12715: {'rouge1': 0.2631578947368421, 'rouge2': 0.16666666666666666, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12716: {'rouge1': 0.2222222222222222, 'rouge2': 0.058823529411764705, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 12717: {'rouge1': 0.2631578947368421, 'rouge2': 0.05555555555555555, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12718: {'rouge1': 0.3684210526315789, 'rouge2': 0.2222222222222222, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12719: {'rouge1': 0.15789473684210525, 'rouge2': 0.1111111111111111, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12720: {'rouge1': 0.3157894736842105, 'rouge2': 0.2777777777777778, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12721: {'rouge1': 0.3157894736842105, 'rouge2': 0.2222222222222222, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12722: {'rouge1': 0.3684210526315789, 'rouge2': 0.3333333333333333, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12723: {'rouge1': 0.42105263157894735, 'rouge2': 0.2222222222222222, 'rougeL': 0.42105263157894735}
# ROUGE scores for sample 12724: {'rouge1': 0.5263157894736842, 'rouge2': 0.5, 'rougeL': 0.5263157894736842}
# ROUGE scores for sample 12725: {'rouge1': 0.47368421052631576, 'rouge2': 0.3888888888888889, 'rougeL': 0.47368421052631576}
# ROUGE scores for sample 12726: {'rouge1': 0.21052631578947367, 'rouge2': 0.0, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12727: {'rouge1': 0.46153846153846156, 'rouge2': 0.3243243243243243, 'rougeL': 0.41025641025641024}
# ROUGE scores for sample 12728: {'rouge1': 0.21052631578947367, 'rouge2': 0.1111111111111111, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12729: {'rouge1': 0.3684210526315789, 'rouge2': 0.2777777777777778, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12730: {'rouge1': 0.35, 'rouge2': 0.2631578947368421, 'rougeL': 0.35}
# ROUGE scores for sample 12731: {'rouge1': 0.5263157894736842, 'rouge2': 0.5, 'rougeL': 0.5263157894736842}
# ROUGE scores for sample 12732: {'rouge1': 0.42105263157894735, 'rouge2': 0.3333333333333333, 'rougeL': 0.42105263157894735}
# ROUGE scores for sample 12733: {'rouge1': 0.21621621621621623, 'rouge2': 0.05714285714285714, 'rougeL': 0.21621621621621623}
# ROUGE scores for sample 12734: {'rouge1': 0.15789473684210525, 'rouge2': 0.0, 'rougeL': 0.10526315789473684}
# ROUGE scores for sample 12735: {'rouge1': 0.10526315789473684, 'rouge2': 0.0, 'rougeL': 0.10526315789473684}
# ROUGE scores for sample 12736: {'rouge1': 0.2631578947368421, 'rouge2': 0.1111111111111111, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12737: {'rouge1': 0.3157894736842105, 'rouge2': 0.2777777777777778, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12738: {'rouge1': 0.2631578947368421, 'rouge2': 0.16666666666666666, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12739: {'rouge1': 0.21052631578947367, 'rouge2': 0.05555555555555555, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12740: {'rouge1': 0.45, 'rouge2': 0.3684210526315789, 'rougeL': 0.45}
# ROUGE scores for sample 12741: {'rouge1': 0.21052631578947367, 'rouge2': 0.16666666666666666, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12742: {'rouge1': 0.2631578947368421, 'rouge2': 0.05555555555555555, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12743: {'rouge1': 0.5, 'rouge2': 0.42105263157894735, 'rougeL': 0.5}
# ROUGE scores for sample 12744: {'rouge1': 0.3243243243243243, 'rouge2': 0.17142857142857143, 'rougeL': 0.3243243243243243}
# ROUGE scores for sample 12745: {'rouge1': 0.3684210526315789, 'rouge2': 0.16666666666666666, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12746: {'rouge1': 0.27027027027027023, 'rouge2': 0.17142857142857143, 'rougeL': 0.27027027027027023}
# ROUGE scores for sample 12747: {'rouge1': 0.3157894736842105, 'rouge2': 0.2777777777777778, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12748: {'rouge1': 0.21052631578947367, 'rouge2': 0.0, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12749: {'rouge1': 0.21621621621621623, 'rouge2': 0.11428571428571428, 'rougeL': 0.21621621621621623}
# ROUGE scores for sample 12750: {'rouge1': 0.21052631578947367, 'rouge2': 0.05555555555555555, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12751: {'rouge1': 0.37837837837837834, 'rouge2': 0.28571428571428575, 'rougeL': 0.37837837837837834}
# ROUGE scores for sample 12752: {'rouge1': 0.7368421052631579, 'rouge2': 0.7222222222222222, 'rougeL': 0.7368421052631579}
# ROUGE scores for sample 12753: {'rouge1': 0.2631578947368421, 'rouge2': 0.2222222222222222, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12754: {'rouge1': 0.21052631578947367, 'rouge2': 0.16666666666666666, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12755: {'rouge1': 0.3684210526315789, 'rouge2': 0.2222222222222222, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12756: {'rouge1': 0.05263157894736842, 'rouge2': 0.0, 'rougeL': 0.05263157894736842}
# ROUGE scores for sample 12757: {'rouge1': 0.4000000000000001, 'rouge2': 0.3684210526315789, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12758: {'rouge1': 0.3243243243243243, 'rouge2': 0.17142857142857143, 'rougeL': 0.3243243243243243}
# ROUGE scores for sample 12759: {'rouge1': 0.2631578947368421, 'rouge2': 0.2222222222222222, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12760: {'rouge1': 0.3157894736842105, 'rouge2': 0.16666666666666666, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12761: {'rouge1': 0.3684210526315789, 'rouge2': 0.2777777777777778, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12762: {'rouge1': 0.16216216216216214, 'rouge2': 0.05714285714285714, 'rougeL': 0.16216216216216214}
# ROUGE scores for sample 12763: {'rouge1': 0.25641025641025644, 'rouge2': 0.10810810810810811, 'rougeL': 0.25641025641025644}
# ROUGE scores for sample 12764: {'rouge1': 0.35, 'rouge2': 0.2631578947368421, 'rougeL': 0.35}
# ROUGE scores for sample 12765: {'rouge1': 0.15789473684210525, 'rouge2': 0.05555555555555555, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12766: {'rouge1': 0.21052631578947367, 'rouge2': 0.1111111111111111, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12767: {'rouge1': 0.3684210526315789, 'rouge2': 0.2777777777777778, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12768: {'rouge1': 0.2631578947368421, 'rouge2': 0.2222222222222222, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12769: {'rouge1': 0.3684210526315789, 'rouge2': 0.2777777777777778, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12770: {'rouge1': 0.358974358974359, 'rouge2': 0.16216216216216214, 'rougeL': 0.3076923076923077}
# ROUGE scores for sample 12771: {'rouge1': 0.15789473684210525, 'rouge2': 0.0, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12772: {'rouge1': 0.47368421052631576, 'rouge2': 0.3888888888888889, 'rougeL': 0.47368421052631576}
# ROUGE scores for sample 12773: {'rouge1': 0.4000000000000001, 'rouge2': 0.3684210526315789, 'rougeL': 0.4000000000000001}
# ROUGE scores for sample 12774: {'rouge1': 0.21052631578947367, 'rouge2': 0.16666666666666666, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12775: {'rouge1': 0.21052631578947367, 'rouge2': 0.16666666666666666, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12776: {'rouge1': 0.3684210526315789, 'rouge2': 0.3333333333333333, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12777: {'rouge1': 0.2631578947368421, 'rouge2': 0.16666666666666666, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12778: {'rouge1': 0.21052631578947367, 'rouge2': 0.1111111111111111, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12779: {'rouge1': 0.15789473684210525, 'rouge2': 0.0, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12780: {'rouge1': 0.15789473684210525, 'rouge2': 0.05555555555555555, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12781: {'rouge1': 0.2631578947368421, 'rouge2': 0.2222222222222222, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12782: {'rouge1': 0.3157894736842105, 'rouge2': 0.2222222222222222, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12783: {'rouge1': 0.35, 'rouge2': 0.21052631578947367, 'rougeL': 0.35}
# ROUGE scores for sample 12784: {'rouge1': 0.3684210526315789, 'rouge2': 0.2777777777777778, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12785: {'rouge1': 0.21052631578947367, 'rouge2': 0.1111111111111111, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12786: {'rouge1': 0.15789473684210525, 'rouge2': 0.05555555555555555, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12787: {'rouge1': 0.10526315789473684, 'rouge2': 0.0, 'rougeL': 0.10526315789473684}
# ROUGE scores for sample 12788: {'rouge1': 0.2631578947368421, 'rouge2': 0.1111111111111111, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12789: {'rouge1': 0.21052631578947367, 'rouge2': 0.1111111111111111, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12790: {'rouge1': 0.37837837837837834, 'rouge2': 0.22857142857142856, 'rougeL': 0.37837837837837834}
# ROUGE scores for sample 12791: {'rouge1': 0.46153846153846156, 'rouge2': 0.05405405405405406, 'rougeL': 0.358974358974359}
# ROUGE scores for sample 12792: {'rouge1': 0.3684210526315789, 'rouge2': 0.2777777777777778, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 12793: {'rouge1': 0.21052631578947367, 'rouge2': 0.16666666666666666, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12794: {'rouge1': 0.5, 'rouge2': 0.47058823529411764, 'rougeL': 0.5}
# ROUGE scores for sample 12795: {'rouge1': 0.3157894736842105, 'rouge2': 0.2222222222222222, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12796: {'rouge1': 0.3157894736842105, 'rouge2': 0.1111111111111111, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12797: {'rouge1': 0.2631578947368421, 'rouge2': 0.0, 'rougeL': 0.15789473684210525}
# ROUGE scores for sample 12798: {'rouge1': 0.21052631578947367, 'rouge2': 0.05555555555555555, 'rougeL': 0.21052631578947367}
# ROUGE scores for sample 12799: {'rouge1': 0.3157894736842105, 'rouge2': 0.16666666666666666, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 12800: {'rouge1': 0.2631578947368421, 'rouge2': 0.2222222222222222, 'rougeL': 0.2631578947368421}
# ROUGE scores for sample 12801: {'rouge1': 0.25, 'rouge2': 0.15789473684210525, 'rougeL': 0.25}
# ROUGE scores for sample 12802: {'rouge1': 0.20000000000000004, 'rouge2': 0.05263157894736842, 'rougeL': 0.15}
# ROUGE scores for sample 12803: {'rouge1': 0.23809523809523808, 'rouge2': 0.10000000000000002, 'rougeL': 0.23809523809523808}
# ROUGE scores for sample 12804: {'rouge1': 0.25, 'rouge2': 0.10526315789473684, 'rougeL': 0.25}
# ROUGE scores for sample 12805: {'rouge1': 0.2857142857142857, 'rouge2': 0.20000000000000004, 'rougeL': 0.2857142857142857}
# ROUGE scores for sample 12806: {'rouge1': 0.15, 'rouge2': 0.05263157894736842, 'rougeL': 0.15}
# ROUGE scores for sample 12807: {'rouge1': 0.15, 'rouge2': 0.0, 'rougeL': 0.15}
# ROUGE scores for sample 12808: {'rouge1': 0.25, 'rouge2': 0.10526315789473684, 'rougeL': 0.25}
# ROUGE scores for sample 12809: {'rouge1': 0.46153846153846156, 'rouge2': 0.37837837837837834, 'rougeL': 0.46153846153846156}
# ROUGE scores for sample 12810: {'rouge1': 0.25, 'rouge2': 0.21052631578947367, 'rougeL': 0.25}
# ROUGE scores for sample 12811: {'rouge1': 0.20000000000000004, 'rouge2': 0.10526315789473684, 'rougeL': 0.20000000000000004}
# ROUGE scores for sample 12812: {'rouge1': 0.15, 'rouge2': 0.05263157894736842, 'rougeL': 0.15}
# ROUGE scores for sample 12813: {'rouge1': 0.45, 'rouge2': 0.42105263157894735, 'rougeL': 0.45}
# ...
# ROUGE scores for sample 17288: {'rouge1': 0.05714285714285714, 'rouge2': 0.0, 'rougeL': 0.05714285714285714}
# ROUGE scores for sample 17289: {'rouge1': 0.3684210526315789, 'rouge2': 0.2222222222222222, 'rougeL': 0.3684210526315789}
# ROUGE scores for sample 17290: {'rouge1': 0.2222222222222222, 'rouge2': 0.11764705882352941, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17291: {'rouge1': 0.16666666666666666, 'rouge2': 0.11764705882352941, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17292: {'rouge1': 0.2777777777777778, 'rouge2': 0.23529411764705882, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17293: {'rouge1': 0.2777777777777778, 'rouge2': 0.11764705882352941, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17294: {'rouge1': 0.3333333333333333, 'rouge2': 0.29411764705882354, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17295: {'rouge1': 0.3888888888888889, 'rouge2': 0.29411764705882354, 'rougeL': 0.3888888888888889}
# ROUGE scores for sample 17296: {'rouge1': 0.3333333333333333, 'rouge2': 0.29411764705882354, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17297: {'rouge1': 0.5263157894736842, 'rouge2': 0.5, 'rougeL': 0.5263157894736842}
# ROUGE scores for sample 17298: {'rouge1': 0.3333333333333333, 'rouge2': 0.23529411764705882, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17299: {'rouge1': 0.2222222222222222, 'rouge2': 0.11764705882352941, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17300: {'rouge1': 0.28571428571428575, 'rouge2': 0.06060606060606061, 'rougeL': 0.22857142857142856}
# ROUGE scores for sample 17301: {'rouge1': 0.4444444444444444, 'rouge2': 0.35294117647058826, 'rougeL': 0.4444444444444444}
# ROUGE scores for sample 17302: {'rouge1': 0.2222222222222222, 'rouge2': 0.058823529411764705, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17303: {'rouge1': 0.3333333333333333, 'rouge2': 0.23529411764705882, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17304: {'rouge1': 0.2222222222222222, 'rouge2': 0.11764705882352941, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17305: {'rouge1': 0.16666666666666666, 'rouge2': 0.0, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17306: {'rouge1': 0.2222222222222222, 'rouge2': 0.0, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17307: {'rouge1': 0.2777777777777778, 'rouge2': 0.23529411764705882, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17308: {'rouge1': 0.2777777777777778, 'rouge2': 0.058823529411764705, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17309: {'rouge1': 0.4444444444444444, 'rouge2': 0.4117647058823529, 'rougeL': 0.4444444444444444}
# ROUGE scores for sample 17310: {'rouge1': 0.1111111111111111, 'rouge2': 0.0, 'rougeL': 0.1111111111111111}
# ROUGE scores for sample 17311: {'rouge1': 0.3888888888888889, 'rouge2': 0.35294117647058826, 'rougeL': 0.3888888888888889}
# ROUGE scores for sample 17312: {'rouge1': 0.47368421052631576, 'rouge2': 0.3888888888888889, 'rougeL': 0.47368421052631576}
# ROUGE scores for sample 17313: {'rouge1': 0.2777777777777778, 'rouge2': 0.17647058823529413, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17314: {'rouge1': 0.16666666666666666, 'rouge2': 0.0, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17315: {'rouge1': 0.2777777777777778, 'rouge2': 0.17647058823529413, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17316: {'rouge1': 0.5, 'rouge2': 0.47058823529411764, 'rougeL': 0.5}
# ROUGE scores for sample 17317: {'rouge1': 0.16666666666666666, 'rouge2': 0.0, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17318: {'rouge1': 0.5263157894736842, 'rouge2': 0.5, 'rougeL': 0.5263157894736842}
# ROUGE scores for sample 17319: {'rouge1': 0.16666666666666666, 'rouge2': 0.0, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17320: {'rouge1': 0.3157894736842105, 'rouge2': 0.2777777777777778, 'rougeL': 0.3157894736842105}
# ROUGE scores for sample 17321: {'rouge1': 0.42105263157894735, 'rouge2': 0.3888888888888889, 'rougeL': 0.42105263157894735}
# ROUGE scores for sample 17322: {'rouge1': 0.23529411764705882, 'rouge2': 0.0625, 'rougeL': 0.23529411764705882}
# ROUGE scores for sample 17323: {'rouge1': 0.37837837837837834, 'rouge2': 0.28571428571428575, 'rougeL': 0.37837837837837834}
# ROUGE scores for sample 17324: {'rouge1': 0.3333333333333333, 'rouge2': 0.23529411764705882, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17325: {'rouge1': 0.2777777777777778, 'rouge2': 0.17647058823529413, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17326: {'rouge1': 0.2222222222222222, 'rouge2': 0.11764705882352941, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17327: {'rouge1': 0.16666666666666666, 'rouge2': 0.058823529411764705, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17328: {'rouge1': 0.34285714285714286, 'rouge2': 0.12121212121212122, 'rougeL': 0.28571428571428575}
# ROUGE scores for sample 17329: {'rouge1': 0.3888888888888889, 'rouge2': 0.23529411764705882, 'rougeL': 0.3888888888888889}
# ROUGE scores for sample 17330: {'rouge1': 0.2222222222222222, 'rouge2': 0.11764705882352941, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17331: {'rouge1': 0.5555555555555556, 'rouge2': 0.5294117647058824, 'rougeL': 0.5555555555555556}
# ROUGE scores for sample 17332: {'rouge1': 0.27027027027027023, 'rouge2': 0.11428571428571428, 'rougeL': 0.21621621621621623}
# ROUGE scores for sample 17333: {'rouge1': 0.3333333333333333, 'rouge2': 0.23529411764705882, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17334: {'rouge1': 0.2777777777777778, 'rouge2': 0.058823529411764705, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17335: {'rouge1': 0.2777777777777778, 'rouge2': 0.17647058823529413, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17336: {'rouge1': 0.2777777777777778, 'rouge2': 0.11764705882352941, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17337: {'rouge1': 0.34285714285714286, 'rouge2': 0.24242424242424243, 'rougeL': 0.34285714285714286}
# ROUGE scores for sample 17338: {'rouge1': 0.16666666666666666, 'rouge2': 0.11764705882352941, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17339: {'rouge1': 0.5, 'rouge2': 0.47058823529411764, 'rougeL': 0.5}
# ROUGE scores for sample 17340: {'rouge1': 0.3888888888888889, 'rouge2': 0.058823529411764705, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17341: {'rouge1': 0.16666666666666666, 'rouge2': 0.11764705882352941, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17342: {'rouge1': 0.3888888888888889, 'rouge2': 0.35294117647058826, 'rougeL': 0.3888888888888889}
# ROUGE scores for sample 17343: {'rouge1': 0.2777777777777778, 'rouge2': 0.17647058823529413, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17344: {'rouge1': 0.22857142857142856, 'rouge2': 0.06060606060606061, 'rougeL': 0.22857142857142856}
# ROUGE scores for sample 17345: {'rouge1': 0.3333333333333333, 'rouge2': 0.23529411764705882, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17346: {'rouge1': 0.2222222222222222, 'rouge2': 0.17647058823529413, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17347: {'rouge1': 0.2222222222222222, 'rouge2': 0.058823529411764705, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17348: {'rouge1': 0.3333333333333333, 'rouge2': 0.29411764705882354, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17349: {'rouge1': 0.6666666666666666, 'rouge2': 0.5294117647058824, 'rougeL': 0.6666666666666666}
# ROUGE scores for sample 17350: {'rouge1': 0.2222222222222222, 'rouge2': 0.058823529411764705, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17351: {'rouge1': 0.3888888888888889, 'rouge2': 0.29411764705882354, 'rougeL': 0.3888888888888889}
# ROUGE scores for sample 17352: {'rouge1': 0.5, 'rouge2': 0.47058823529411764, 'rougeL': 0.5}
# ROUGE scores for sample 17353: {'rouge1': 0.2777777777777778, 'rouge2': 0.23529411764705882, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17354: {'rouge1': 0.3333333333333333, 'rouge2': 0.23529411764705882, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17355: {'rouge1': 0.4444444444444444, 'rouge2': 0.4117647058823529, 'rougeL': 0.4444444444444444}
# ROUGE scores for sample 17356: {'rouge1': 0.3243243243243243, 'rouge2': 0.22857142857142856, 'rougeL': 0.3243243243243243}
# ROUGE scores for sample 17357: {'rouge1': 0.3333333333333333, 'rouge2': 0.23529411764705882, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17358: {'rouge1': 0.37837837837837834, 'rouge2': 0.22857142857142856, 'rougeL': 0.37837837837837834}
# ROUGE scores for sample 17359: {'rouge1': 0.3333333333333333, 'rouge2': 0.29411764705882354, 'rougeL': 0.3333333333333333}
# ROUGE scores for sample 17360: {'rouge1': 0.2222222222222222, 'rouge2': 0.11764705882352941, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17361: {'rouge1': 0.16666666666666666, 'rouge2': 0.058823529411764705, 'rougeL': 0.16666666666666666}
# ROUGE scores for sample 17362: {'rouge1': 0.29411764705882354, 'rouge2': 0.1875, 'rougeL': 0.29411764705882354}
# ROUGE scores for sample 17363: {'rouge1': 0.2777777777777778, 'rouge2': 0.23529411764705882, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17364: {'rouge1': 0.22857142857142856, 'rouge2': 0.06060606060606061, 'rougeL': 0.22857142857142856}
# ROUGE scores for sample 17365: {'rouge1': 0.22857142857142856, 'rouge2': 0.06060606060606061, 'rougeL': 0.22857142857142856}
# ROUGE scores for sample 17366: {'rouge1': 0.3888888888888889, 'rouge2': 0.23529411764705882, 'rougeL': 0.3888888888888889}
# ROUGE scores for sample 17367: {'rouge1': 0.42424242424242425, 'rouge2': 0.19354838709677422, 'rougeL': 0.3636363636363636}
# ROUGE scores for sample 17368: {'rouge1': 0.2777777777777778, 'rouge2': 0.23529411764705882, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17369: {'rouge1': 0.2222222222222222, 'rouge2': 0.11764705882352941, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17370: {'rouge1': 0.2222222222222222, 'rouge2': 0.17647058823529413, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17371: {'rouge1': 0.2777777777777778, 'rouge2': 0.11764705882352941, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17372: {'rouge1': 0.1111111111111111, 'rouge2': 0.0, 'rougeL': 0.1111111111111111}
# ROUGE scores for sample 17373: {'rouge1': 0.2222222222222222, 'rouge2': 0.058823529411764705, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17374: {'rouge1': 0.2222222222222222, 'rouge2': 0.0, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17375: {'rouge1': 0.2777777777777778, 'rouge2': 0.23529411764705882, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17376: {'rouge1': 0.5263157894736842, 'rouge2': 0.5, 'rougeL': 0.5263157894736842}
# ROUGE scores for sample 17377: {'rouge1': 0.2222222222222222, 'rouge2': 0.058823529411764705, 'rougeL': 0.2222222222222222}
# ROUGE scores for sample 17378: {'rouge1': 0.6111111111111112, 'rouge2': 0.5882352941176471, 'rougeL': 0.6111111111111112}
# ROUGE scores for sample 17379: {'rouge1': 0.1111111111111111, 'rouge2': 0.0, 'rougeL': 0.1111111111111111}
# ROUGE scores for sample 17380: {'rouge1': 0.5, 'rouge2': 0.47058823529411764, 'rougeL': 0.5}
# ROUGE scores for sample 17381: {'rouge1': 0.28571428571428575, 'rouge2': 0.24242424242424243, 'rougeL': 0.28571428571428575}
# ROUGE scores for sample 17382: {'rouge1': 0.22857142857142856, 'rouge2': 0.12121212121212122, 'rougeL': 0.22857142857142856}
# ROUGE scores for sample 17383: {'rouge1': 0.47368421052631576, 'rouge2': 0.3888888888888889, 'rougeL': 0.47368421052631576}
# ROUGE scores for sample 17384: {'rouge1': 0.47058823529411764, 'rouge2': 0.25, 'rougeL': 0.47058823529411764}
# ROUGE scores for sample 17385: {'rouge1': 0.3333333333333333, 'rouge2': 0.11764705882352941, 'rougeL': 0.2777777777777778}
# ROUGE scores for sample 17386: {'rouge1': 0.1111111111111111, 'rouge2': 0.0, 'rougeL': 0.1111111111111111}
# ROUGE scores for sample 17387: {'rouge1': 0.4444444444444444, 'rouge2': 0.11764705882352941, 'rougeL': 0.4444444444444444}
# METEOR scores: [0.3128507295173962, 0.23232323232323232, 0.21799628942486085, 0.1590909090909091, 0.36079545454545453, 0.1434659090909091, 0.20272727272727276, 0.1690909090909091, 0.3144712430426716, 0.1434659090909091, 0.5769944341372912, 0.3484848484848485, 0.2676767676767677, 0.2556818181818182, 0.045454545454545456, 0.34090909090909094, 0.5898332436793976, 0.34090909090909094, 0.2676767676767677, 0.1938131313131313, 0.448409090909091, 0.2556818181818182, 0.20272727272727276, 0.40151515151515155, 0.1690909090909091, 0.23232323232323232, 0.20272727272727276, 0.42613636363636365, 0.2884972170686456, 0.1690909090909091, 0.11363636363636365, 0.20272727272727276, 0.3144712430426716, 0.3056586270871985, 0.11363636363636365, 0.1938131313131313, 0.4068462401795735, 0.4068462401795735, 0.3911335578002245, 0.2884972170686456, 0.3144712430426716, 0.5441919191919192, 0.1434659090909091, 0.3056586270871985, 0.40151515151515155, 0.448409090909091, 0.20272727272727276, 0.2556818181818182, 0.13636363636363635, 0.1690909090909091, 0.13636363636363635, 0.3056586270871985, 0.5447821409359871, 0.448409090909091, 0.06818181818181818, 0.3056586270871985, 0.09090909090909091, 0.3144712430426716, 0.4068462401795735, 0.3911335578002245, 0.2556818181818182, 0.20272727272727276, 0.4068462401795735, 0.3144712430426716, 0.06818181818181818, 0.11363636363636365, 0.2556818181818182, 0.20272727272727276, 0.2556818181818182, 0.1434659090909091, 0.3144712430426716, 0.3144712430426716, 0.23232323232323232, 0.3056586270871985, 0.260204081632653, 0.1938131313131313, 0.42613636363636365, 0.20272727272727276, 0.1434659090909091, 0.13636363636363635, 0.3056586270871985, 0.13636363636363635, 0.20272727272727276, 0.1690909090909091, 0.1434659090909091, 0.22, 0.22, 0.3144712430426716, 0.11616161616161616, 0.3056586270871985, 0.20272727272727276, 0.36079545454545453, 0.11363636363636365, 0.40151515151515155, 0.3630728775356874, 0.24183238636363638, 0.06818181818181818, 0.23232323232323232, 0.35404829545454547, 0.49849737039819686, 0.49849737039819686, 0.2869318181818182, 0.1434659090909091, 0.2884972170686456, 0.4068462401795735, 0.4068462401795735, 0.06818181818181818, 0.2556818181818182, 0.22, 0.3911335578002245, 0.23232323232323232, 0.3144712430426716, 0.23232323232323232, 0.35404829545454547, 0.2676767676767677, 0.3144712430426716, 0.2556818181818182, 0.06818181818181818, 0.40151515151515155, 0.3056586270871985, 0.35404829545454547, 0.22, 0.09090909090909091, 0.49849737039819686, 0.20272727272727276, 0.1938131313131313, 0.1690909090909091, 0.17045454545454547, 0.234375, 0.3680555555555556, 0.2385204081632653, 0.21296296296296297, 0.26445578231292516, 0.08333333333333333, 0.15500000000000003, 0.26445578231292516, 0.0625, 0.08333333333333333, 0.666015625, 0.234375, 0.234375, 0.08333333333333333, 0.21296296296296297, 0.33072916666666663, 0.280187074829932, 0.15500000000000003, 0.3245442708333333, 0.3452083333333334, 0.2016666666666667, 0.3125, 0.15500000000000003, 0.24537037037037038, 0.3680555555555556, 0.18583333333333338, 0.280187074829932, 0.21296296296296297, 0.33072916666666663, 0.2385204081632653, 0.18583333333333338, 0.280187074829932, 0.08333333333333333, 0.2016666666666667, 0.17766203703703703, 0.280187074829932, 0.280187074829932, 0.10416666666666669, 0.08333333333333333, 0.29264322916666663, 0.4033333333333334, 0.280187074829932, 0.234375, 0.234375, 0.15500000000000003, 0.18583333333333338, 0.0625, 0.3680555555555556, 0.4150000000000001, 0.4536845730027548, 0.288265306122449, 0.08333333333333333, 0.10416666666666669, 0.234375, 0.0625, 0.26445578231292516, 0.10416666666666669, 0.10416666666666669, 0.2867798353909465, 0.3428497942386831, 0.29264322916666663, 0.234375, 0.0625, 0.2867798353909465, 0.3680555555555556, 0.21296296296296297, 0.3428497942386831, 0.10416666666666669, 0.33072916666666663, 0.3245442708333333, 0.18583333333333338, 0.3729423868312757, 0.18583333333333338, 0.3245442708333333, 0.21296296296296297, 0.3125, 0.15500000000000003, 0.08333333 ...

# %% [markdown]
# **Save and Load Model**

# %%
# Save model weights
def save_model(model, filepath):
    torch.save(model.state_dict(), filepath)
    print(f"Model saved to {filepath}")

# Example usage after training
save_model(model, "model_weights.pth")

# Load the model's weights
def load_model(model, filepath, device):
    model.load_state_dict(torch.load(filepath, map_location=device))
    model.to(device)  # Ensure model is on the right device (CPU or GPU)
    model.eval()  # Set the model to evaluation mode
    print(f"Model loaded from {filepath}")

# Example usage
load_model(model, "model_weights.pth", device)

# %% [markdown]
# **Inference Testing**

# %%
def infer_english_to_french(model, sentence, en_vocab, fr_vocab, device):
    model.eval()

    # Tokenize and numericalize the input sentence (English)
    tokenized_sentence = sentence.split()  # Use the same tokenization method as in training (or use spacy/nltk)
    print(f"Tokenized input (English): {tokenized_sentence}")  # Check tokenization

    # Convert sentence to tensor (use en_vocab to map words to indices)
    sentence_tensor = torch.tensor([en_vocab[token] for token in tokenized_sentence if token in en_vocab]).unsqueeze(0).to(device)

    # Handle any out-of-vocabulary words in the tokenized sentence
    oov_tokens = [token for token in tokenized_sentence if token not in en_vocab]
    if oov_tokens:
        print(f"Out of vocabulary tokens: {oov_tokens}")

    # Generate predictions using the trained model
    with torch.no_grad():
        output = model(sentence_tensor, sentence_tensor, teacher_forcing_ratio=0)  # No teacher forcing during inference

    # Convert predicted tokens (French) from the model's output
    predicted_tokens = []
    for i in range(output.shape[1]):  # Iterate through the timesteps
        prediction = output[:, i, :].argmax(dim=1)  # Get the predicted word ID
        predicted_word = fr_vocab.lookup_token(prediction.item())  # Convert ID to word (French)
        predicted_tokens.append(predicted_word)

    # Join tokens into a string (French translation)
    predicted_sentence = ' '.join(predicted_tokens)
    return predicted_sentence


# Example usage
sentence = "Hello, today it will rain heavily"  # English sentence
predicted_translation = infer_english_to_french(model, sentence, en_vocab, fr_vocab, device)

print(f"Predicted French translation: {predicted_translation}")
# Out:
# Tokenized input (English): ['Hello,', 'today', 'it', 'will', 'rain', 'heavily']
# Out of vocabulary tokens: ['Hello,']
# Predicted French translation: <unk> <unk> <unk> <unk> <unk>
